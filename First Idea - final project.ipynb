# %%
from __future__ import print_function
import json
import sys
from os.path import join, dirname
from watson_developer_cloud import ToneAnalyzerV3
import lyricwikia



tone_analyzer = ToneAnalyzerV3(
    username = "05c73eca-6185-4133-97c7-7b022cb89427",
    password = "jgDiIMTC4sON",
    version = '2017-09-26')

lyric = lyricwikia.get_lyrics('Dragonforce', 'Through the Fire and Flames')



fh = open('lyrics.js', 'w+')

fh.write(lyric)

fh.close()


f = open('lyrics.js', 'r+')

print("\ntone_chat() Dragonforce - Through the fire and flames:\n")

jsonParsing = []
for line in f.readlines():

    content_type = 'text/plain'
    tone = tone_analyzer.tone({"text": line}, content_type)
    jsonText = json.dumps(tone, indent=2)
    jsonParse = json.loads(jsonText)
    jsonParsing.extend(jsonParse["document_tone"]["tones"])  
   
    
f.close()

emotions = []
m = []

for i in range(len(jsonParsing)):
    m = jsonParsing[i]["tone_name"]
    

    emotions.extend([m])
    
print(emotions)

for i in range(len(emotions)):
    if emotions[i] == 'Anger':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FirstPlanet = prompt('First planet to be created', '1')\n \nvar cold = 'ice1'\nvar iter = i.toString();\nvar n = cold.replace('1', iter)"
 
        a = open('SongTranslation1.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()
    elif emotions[i] == 'Excitement':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar SecondPlanet = prompt('Second planet to be created', '1')\n \nvar cold = 'ice2'\nvar iter = i.toString();\nvar n = cold.replace('2', iter)"
 
        b = open('SongTranslation2.jsx', 'w+')

        b.write(jsxTranslation)

        b.close()

    elif emotions[i] == 'Fear':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar ThirdPlanet = prompt('Third planet to be created', '3')\n \nvar cold = 'ice1'\nvar iter = i.toString();\nvar n = cold.replace('1', iter)"
 
        c = open('SongTranslation3.jsx', 'w+')

        c.write(jsxTranslation)

        c.close()

    elif emotions[i] == 'Joy':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FirstPlanet = prompt('First planet to be created', '1')\n \nvar cold = 'ice3'\nvar iter = i.toString();\nvar n = cold.replace('3', iter)"
 
        a = open('SongTranslation4.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()
   
    elif emotions[i] == 'Sadness':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FourthPlanet = prompt('Fourth planet to be created', '4')\n \nvar fire = 'fire1'\nvar iter = i.toString();\nvar n = fire.replace('4', iter)"
 
        a = open('SongTranslation5.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()

    elif emotions[i] == 'Analytical':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FifthPlanet = prompt('Fifth planet to be created', '1')\n \nvar fire = 'fire2'\nvar iter = i.toString();\nvar n = fire.replace('5', iter)"
 
        a = open('SongTranslation6.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()

    elif emotions[i] == 'Confident':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar SixthPlanet = prompt('Sixth planet to be created', '6')\n \nvar fire = 'fire3'\nvar iter = i.toString();\nvar n = fire.replace('6', iter)"
 
        a = open('SongTranslation7.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()

    elif emotions[i] == 'Tentative':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FirstPlanet = prompt('Seventh planet to be created', '7')\n \nvar sand = 'sand1'\nvar iter = i.toString();\nvar n = sand.replace('7', iter)"
 
        a = open('SongTranslation8.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()

    elif emotions[i] == 'Impolite':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar EighthPlanet = prompt('Eighth planet to be created', '8')\n \nvar sand = 'sand2'\nvar iter = i.toString();\nvar n = sand.replace('8', iter)"
 
        a = open('SongTranslation9.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()

    elif emotions[i] == 'Frustration':
        jsxTranslation = "var Song = app.project.activeItem\nvar Planet = Song.selectedLayers[0];\nVar numMarkers = Planet.marker.numKeys;\n \nFor(i=1; i<= numMarkers; i++)\n{\n \nVar iteration = 1 + i % 2; \nSong.layer(iteration).startTime = Planet.marker.keyTime(i); \n \nIteration = 4 + i % 2; \n}\n \n \nvar FirstPlanet = prompt('Ninth planet to be created', '9')\n \nvar sand = 'sand3'\nvar iter = i.toString();\nvar n = sand.replace('9', iter)"
 
        a = open('SongTranslation10.jsx', 'w+')

        a.write(jsxTranslation)

        a.close()
# Out:
# tone_chat() Dragonforce - Through the fire and flames:
#
# ['Joy', 'Tentative', 'Sadness', 'Analytical', 'Joy', 'Confident', 'Analytical', 'Sadness', 'Confident', 'Sadness', 'Tentative', 'Confident', 'Analytical', 'Confident', 'Confident', 'Analytical', 'Confident', 'Analytical', 'Sadness', 'Confident', 'Sadness', 'Fear', 'Tentative', 'Confident', 'Analytical', 'Sadness', 'Confident', 'Sadness']
